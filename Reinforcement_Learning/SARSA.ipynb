# %%
# !pip install "gymnasium[toy_text]"

# %%
import gymnasium as gym
import numpy as np
import random as rd

# %%
env = gym.make('CliffWalking-v1')

starting_state, _ = env.reset()

# %% [markdown]
# ## SARSA - Start -> Action -> Reward -> Next start -> Next Action

# %%
gamma = 0.99
alpha = 0.5
epsilon = 0.1
episodes = 500

# %%
# Q-table -> action values
Q = np.zeros((48, 4))

# %%
def epsilon_greedy(state):
    if rd.random() < epsilon:
        return env.action_space.sample() # -> Explore
    else:
        return np.argmax(Q[state]) # -> Exploit

# %%
for episode in range(episodes):
    render = (episode % 50 == 0)
    # if render:
    #     env = gym.make('CliffWalking-v1', render_mode='human')
    
    # else:
    #     env = gym.make('CliffWalking-v1')

    done = False # when the episode
    state, _ = env.reset()
    action = epsilon_greedy(state)

    total_reward = 0
    episode_len = 0

    while not done:
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        next_action = epsilon_greedy(next_state)

        # SARSA

        Q[state, action] += alpha * (reward + gamma * (Q[next_state, next_action]-  Q[state, action]))

        state = next_state
        action = next_action

        total_reward += reward
        episode_len += 1
    print(f"Episode: {episode+1}, Total Reward: {total_reward} & Episode Len = {episode_len}")
env.close()
# Out:
# Episode: 1, Total Reward: -101 & Episode Len = 101
# Episode: 2, Total Reward: -1685 & Episode Len = 497
# Episode: 3, Total Reward: -301 & Episode Len = 202
# Episode: 4, Total Reward: -80 & Episode Len = 80
# Episode: 5, Total Reward: -75 & Episode Len = 75
# Episode: 6, Total Reward: -82 & Episode Len = 82
# Episode: 7, Total Reward: -53 & Episode Len = 53
# Episode: 8, Total Reward: -76 & Episode Len = 76
# Episode: 9, Total Reward: -45 & Episode Len = 45
# Episode: 10, Total Reward: -71 & Episode Len = 71
# Episode: 11, Total Reward: -414 & Episode Len = 117
# Episode: 12, Total Reward: -441 & Episode Len = 144
# Episode: 13, Total Reward: -149 & Episode Len = 50
# Episode: 14, Total Reward: -55 & Episode Len = 55
# Episode: 15, Total Reward: -35 & Episode Len = 35
# Episode: 16, Total Reward: -206 & Episode Len = 107
# Episode: 17, Total Reward: -45 & Episode Len = 45
# Episode: 18, Total Reward: -186 & Episode Len = 87
# Episode: 19, Total Reward: -33 & Episode Len = 33
# ...

# %%
env = gym.make('CliffWalking-v1', render_mode='human')

state, _ = env.reset()
done = False
total_reward = 0
episode_len = 0

while not done:
    action = np.argmax(Q[state])
    state, reward, terminated, truncated, _  = env.step(action)
    done = terminated or truncated

    total_reward += reward
    episode_len += 1

print(f"Total Reward: {total_reward} & Episode Len = {episode_len}")
env.close()
# Out:
# Total Reward: -17 & Episode Len = 17
