# %%
import gymnasium as gym
import numpy as np
import random as rd

# %%
gamma = 0.99
alpha = 0.5
epsilon = 0.1
episodes = 500

# %%
Q = np.zeros((48, 4))

# %%
def epsilon_greedy(state):
    if rd.random() < epsilon:
        return env.action_space.sample()
    else:
        return np.argmax(Q[state])

# %%
for episode in range(episodes):
    render = (episode % 500 == 0)

    if render:
        env = gym.make('CliffWalking-v1', render_mode="human")
    else:
        env = gym.make('CliffWalking-v1')
    done = False
    state, _ = env.reset()

    episode_len = 0
    total_reward = 0

    while not done:
        action = epsilon_greedy(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        Q[state, action] += alpha + (reward + gamma * np.max(Q[next_state]) - Q[state, action])
        state = next_state
        episode_len += 1
        total_reward += reward


    print(f"Episod = {episode+1} / 500 & Total Reward = {total_reward} & Episode Length: {episode_len}")
    env.close()
# Out:
# Episod = 1 / 500 & Total Reward = -353 & Episode Length: 155
# Episod = 2 / 500 & Total Reward = -1201 & Episode Length: 310
# Episod = 3 / 500 & Total Reward = -163 & Episode Length: 64
# Episod = 4 / 500 & Total Reward = -285 & Episode Length: 87
# Episod = 5 / 500 & Total Reward = -152 & Episode Length: 53
# Episod = 6 / 500 & Total Reward = -153 & Episode Length: 54
# Episod = 7 / 500 & Total Reward = -38 & Episode Length: 38
# Episod = 8 / 500 & Total Reward = -46 & Episode Length: 46
# Episod = 9 / 500 & Total Reward = -46 & Episode Length: 46
# Episod = 10 / 500 & Total Reward = -29 & Episode Length: 29
# Episod = 11 / 500 & Total Reward = -147 & Episode Length: 48
# Episod = 12 / 500 & Total Reward = -261 & Episode Length: 63
# Episod = 13 / 500 & Total Reward = -36 & Episode Length: 36
# Episod = 14 / 500 & Total Reward = -33 & Episode Length: 33
# Episod = 15 / 500 & Total Reward = -32 & Episode Length: 32
# Episod = 16 / 500 & Total Reward = -27 & Episode Length: 27
# Episod = 17 / 500 & Total Reward = -271 & Episode Length: 73
# Episod = 18 / 500 & Total Reward = -27 & Episode Length: 27
# Episod = 19 / 500 & Total Reward = -135 & Episode Length: 36
# Episod = 20 / 500 & Total Reward = -23 & Episode Length: 23
# Episod = 21 / 500 & Total Reward = -33 & Episode Length: 33
# Episod = 22 / 500 & Total Reward = -24 & Episode Length: 24
# Episod = 23 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 24 / 500 & Total Reward = -18 & Episode Length: 18
# Episod = 25 / 500 & Total Reward = -29 & Episode Length: 29
# Episod = 26 / 500 & Total Reward = -25 & Episode Length: 25
# Episod = 27 / 500 & Total Reward = -128 & Episode Length: 29
# Episod = 28 / 500 & Total Reward = -140 & Episode Length: 41
# Episod = 29 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 30 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 31 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 32 / 500 & Total Reward = -120 & Episode Length: 21
# Episod = 33 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 34 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 35 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 36 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 37 / 500 & Total Reward = -116 & Episode Length: 17
# Episod = 38 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 39 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 40 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 41 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 42 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 43 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 44 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 45 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 46 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 47 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 48 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 49 / 500 & Total Reward = -228 & Episode Length: 30
# Episod = 50 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 51 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 52 / 500 & Total Reward = -113 & Episode Length: 14
# Episod = 53 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 54 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 55 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 56 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 57 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 58 / 500 & Total Reward = -229 & Episode Length: 31
# Episod = 59 / 500 & Total Reward = -232 & Episode Length: 34
# Episod = 60 / 500 & Total Reward = -119 & Episode Length: 20
# Episod = 61 / 500 & Total Reward = -116 & Episode Length: 17
# Episod = 62 / 500 & Total Reward = -118 & Episode Length: 19
# Episod = 63 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 64 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 65 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 66 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 67 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 68 / 500 & Total Reward = -222 & Episode Length: 24
# Episod = 69 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 70 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 71 / 500 & Total Reward = -22 & Episode Length: 22
# Episod = 72 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 73 / 500 & Total Reward = -22 & Episode Length: 22
# Episod = 74 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 75 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 76 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 77 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 78 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 79 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 80 / 500 & Total Reward = -114 & Episode Length: 15
# Episod = 81 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 82 / 500 & Total Reward = -226 & Episode Length: 28
# Episod = 83 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 84 / 500 & Total Reward = -21 & Episode Length: 21
# Episod = 85 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 86 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 87 / 500 & Total Reward = -118 & Episode Length: 19
# Episod = 88 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 89 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 90 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 91 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 92 / 500 & Total Reward = -20 & Episode Length: 20
# Episod = 93 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 94 / 500 & Total Reward = -226 & Episode Length: 28
# Episod = 95 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 96 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 97 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 98 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 99 / 500 & Total Reward = -23 & Episode Length: 23
# Episod = 100 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 101 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 102 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 103 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 104 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 105 / 500 & Total Reward = -116 & Episode Length: 17
# Episod = 106 / 500 & Total Reward = -122 & Episode Length: 23
# Episod = 107 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 108 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 109 / 500 & Total Reward = -130 & Episode Length: 31
# Episod = 110 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 111 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 112 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 113 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 114 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 115 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 116 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 117 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 118 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 119 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 120 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 121 / 500 & Total Reward = -123 & Episode Length: 24
# Episod = 122 / 500 & Total Reward = -125 & Episode Length: 26
# Episod = 123 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 124 / 500 & Total Reward = -120 & Episode Length: 21
# Episod = 125 / 500 & Total Reward = -128 & Episode Length: 29
# Episod = 126 / 500 & Total Reward = -231 & Episode Length: 33
# Episod = 127 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 128 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 129 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 130 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 131 / 500 & Total Reward = -121 & Episode Length: 22
# Episod = 132 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 133 / 500 & Total Reward = -123 & Episode Length: 24
# Episod = 134 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 135 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 136 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 137 / 500 & Total Reward = -115 & Episode Length: 16
# Episod = 138 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 139 / 500 & Total Reward = -128 & Episode Length: 29
# Episod = 140 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 141 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 142 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 143 / 500 & Total Reward = -18 & Episode Length: 18
# Episod = 144 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 145 / 500 & Total Reward = -113 & Episode Length: 14
# Episod = 146 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 147 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 148 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 149 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 150 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 151 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 152 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 153 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 154 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 155 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 156 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 157 / 500 & Total Reward = -122 & Episode Length: 23
# Episod = 158 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 159 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 160 / 500 & Total Reward = -124 & Episode Length: 25
# Episod = 161 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 162 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 163 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 164 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 165 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 166 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 167 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 168 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 169 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 170 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 171 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 172 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 173 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 174 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 175 / 500 & Total Reward = -125 & Episode Length: 26
# Episod = 176 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 177 / 500 & Total Reward = -123 & Episode Length: 24
# Episod = 178 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 179 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 180 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 181 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 182 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 183 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 184 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 185 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 186 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 187 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 188 / 500 & Total Reward = -120 & Episode Length: 21
# Episod = 189 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 190 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 191 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 192 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 193 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 194 / 500 & Total Reward = -123 & Episode Length: 24
# Episod = 195 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 196 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 197 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 198 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 199 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 200 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 201 / 500 & Total Reward = -234 & Episode Length: 36
# Episod = 202 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 203 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 204 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 205 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 206 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 207 / 500 & Total Reward = -115 & Episode Length: 16
# Episod = 208 / 500 & Total Reward = -120 & Episode Length: 21
# Episod = 209 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 210 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 211 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 212 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 213 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 214 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 215 / 500 & Total Reward = -121 & Episode Length: 22
# Episod = 216 / 500 & Total Reward = -119 & Episode Length: 20
# Episod = 217 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 218 / 500 & Total Reward = -219 & Episode Length: 21
# Episod = 219 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 220 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 221 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 222 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 223 / 500 & Total Reward = -20 & Episode Length: 20
# Episod = 224 / 500 & Total Reward = -122 & Episode Length: 23
# Episod = 225 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 226 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 227 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 228 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 229 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 230 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 231 / 500 & Total Reward = -120 & Episode Length: 21
# Episod = 232 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 233 / 500 & Total Reward = -215 & Episode Length: 17
# Episod = 234 / 500 & Total Reward = -126 & Episode Length: 27
# Episod = 235 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 236 / 500 & Total Reward = -20 & Episode Length: 20
# Episod = 237 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 238 / 500 & Total Reward = -121 & Episode Length: 22
# Episod = 239 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 240 / 500 & Total Reward = -132 & Episode Length: 33
# Episod = 241 / 500 & Total Reward = -229 & Episode Length: 31
# Episod = 242 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 243 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 244 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 245 / 500 & Total Reward = -228 & Episode Length: 30
# Episod = 246 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 247 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 248 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 249 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 250 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 251 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 252 / 500 & Total Reward = -115 & Episode Length: 16
# Episod = 253 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 254 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 255 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 256 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 257 / 500 & Total Reward = -113 & Episode Length: 14
# Episod = 258 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 259 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 260 / 500 & Total Reward = -128 & Episode Length: 29
# Episod = 261 / 500 & Total Reward = -122 & Episode Length: 23
# Episod = 262 / 500 & Total Reward = -123 & Episode Length: 24
# Episod = 263 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 264 / 500 & Total Reward = -20 & Episode Length: 20
# Episod = 265 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 266 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 267 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 268 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 269 / 500 & Total Reward = -231 & Episode Length: 33
# Episod = 270 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 271 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 272 / 500 & Total Reward = -123 & Episode Length: 24
# Episod = 273 / 500 & Total Reward = -116 & Episode Length: 17
# Episod = 274 / 500 & Total Reward = -123 & Episode Length: 24
# Episod = 275 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 276 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 277 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 278 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 279 / 500 & Total Reward = -335 & Episode Length: 38
# Episod = 280 / 500 & Total Reward = -122 & Episode Length: 23
# Episod = 281 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 282 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 283 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 284 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 285 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 286 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 287 / 500 & Total Reward = -124 & Episode Length: 25
# Episod = 288 / 500 & Total Reward = -120 & Episode Length: 21
# Episod = 289 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 290 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 291 / 500 & Total Reward = -116 & Episode Length: 17
# Episod = 292 / 500 & Total Reward = -125 & Episode Length: 26
# Episod = 293 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 294 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 295 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 296 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 297 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 298 / 500 & Total Reward = -116 & Episode Length: 17
# Episod = 299 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 300 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 301 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 302 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 303 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 304 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 305 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 306 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 307 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 308 / 500 & Total Reward = -22 & Episode Length: 22
# Episod = 309 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 310 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 311 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 312 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 313 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 314 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 315 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 316 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 317 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 318 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 319 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 320 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 321 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 322 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 323 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 324 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 325 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 326 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 327 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 328 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 329 / 500 & Total Reward = -229 & Episode Length: 31
# Episod = 330 / 500 & Total Reward = -21 & Episode Length: 21
# Episod = 331 / 500 & Total Reward = -124 & Episode Length: 25
# Episod = 332 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 333 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 334 / 500 & Total Reward = -127 & Episode Length: 28
# Episod = 335 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 336 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 337 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 338 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 339 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 340 / 500 & Total Reward = -123 & Episode Length: 24
# Episod = 341 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 342 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 343 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 344 / 500 & Total Reward = -127 & Episode Length: 28
# Episod = 345 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 346 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 347 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 348 / 500 & Total Reward = -126 & Episode Length: 27
# Episod = 349 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 350 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 351 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 352 / 500 & Total Reward = -121 & Episode Length: 22
# Episod = 353 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 354 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 355 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 356 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 357 / 500 & Total Reward = -124 & Episode Length: 25
# Episod = 358 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 359 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 360 / 500 & Total Reward = -21 & Episode Length: 21
# Episod = 361 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 362 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 363 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 364 / 500 & Total Reward = -18 & Episode Length: 18
# Episod = 365 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 366 / 500 & Total Reward = -121 & Episode Length: 22
# Episod = 367 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 368 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 369 / 500 & Total Reward = -130 & Episode Length: 31
# Episod = 370 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 371 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 372 / 500 & Total Reward = -120 & Episode Length: 21
# Episod = 373 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 374 / 500 & Total Reward = -113 & Episode Length: 14
# Episod = 375 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 376 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 377 / 500 & Total Reward = -21 & Episode Length: 21
# Episod = 378 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 379 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 380 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 381 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 382 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 383 / 500 & Total Reward = -124 & Episode Length: 25
# Episod = 384 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 385 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 386 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 387 / 500 & Total Reward = -118 & Episode Length: 19
# Episod = 388 / 500 & Total Reward = -217 & Episode Length: 19
# Episod = 389 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 390 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 391 / 500 & Total Reward = -222 & Episode Length: 24
# Episod = 392 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 393 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 394 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 395 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 396 / 500 & Total Reward = -116 & Episode Length: 17
# Episod = 397 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 398 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 399 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 400 / 500 & Total Reward = -115 & Episode Length: 16
# Episod = 401 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 402 / 500 & Total Reward = -119 & Episode Length: 20
# Episod = 403 / 500 & Total Reward = -125 & Episode Length: 26
# Episod = 404 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 405 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 406 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 407 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 408 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 409 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 410 / 500 & Total Reward = -122 & Episode Length: 23
# Episod = 411 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 412 / 500 & Total Reward = -116 & Episode Length: 17
# Episod = 413 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 414 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 415 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 416 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 417 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 418 / 500 & Total Reward = -119 & Episode Length: 20
# Episod = 419 / 500 & Total Reward = -121 & Episode Length: 22
# Episod = 420 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 421 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 422 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 423 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 424 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 425 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 426 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 427 / 500 & Total Reward = -119 & Episode Length: 20
# Episod = 428 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 429 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 430 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 431 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 432 / 500 & Total Reward = -118 & Episode Length: 19
# Episod = 433 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 434 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 435 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 436 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 437 / 500 & Total Reward = -115 & Episode Length: 16
# Episod = 438 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 439 / 500 & Total Reward = -121 & Episode Length: 22
# Episod = 440 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 441 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 442 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 443 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 444 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 445 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 446 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 447 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 448 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 449 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 450 / 500 & Total Reward = -120 & Episode Length: 21
# Episod = 451 / 500 & Total Reward = -124 & Episode Length: 25
# Episod = 452 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 453 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 454 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 455 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 456 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 457 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 458 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 459 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 460 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 461 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 462 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 463 / 500 & Total Reward = -19 & Episode Length: 19
# Episod = 464 / 500 & Total Reward = -17 & Episode Length: 17
# Episod = 465 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 466 / 500 & Total Reward = -229 & Episode Length: 31
# Episod = 467 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 468 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 469 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 470 / 500 & Total Reward = -126 & Episode Length: 27
# Episod = 471 / 500 & Total Reward = -119 & Episode Length: 20
# Episod = 472 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 473 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 474 / 500 & Total Reward = -121 & Episode Length: 22
# Episod = 475 / 500 & Total Reward = -113 & Episode Length: 14
# Episod = 476 / 500 & Total Reward = -121 & Episode Length: 22
# Episod = 477 / 500 & Total Reward = -116 & Episode Length: 17
# Episod = 478 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 479 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 480 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 481 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 482 / 500 & Total Reward = -16 & Episode Length: 16
# Episod = 483 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 484 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 485 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 486 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 487 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 488 / 500 & Total Reward = -115 & Episode Length: 16
# Episod = 489 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 490 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 491 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 492 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 493 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 494 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 495 / 500 & Total Reward = -14 & Episode Length: 14
# Episod = 496 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 497 / 500 & Total Reward = -15 & Episode Length: 15
# Episod = 498 / 500 & Total Reward = -117 & Episode Length: 18
# Episod = 499 / 500 & Total Reward = -13 & Episode Length: 13
# Episod = 500 / 500 & Total Reward = -13 & Episode Length: 13

# %%
# What did agent Learn

env = gym.make('CliffWalking-v1', render_mode='human')
state,_ = env.reset()
total_reward = 0
episode_len = 0
done = False
while not done:
    action = np.argmax(Q[state])
    state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    
    episode_len += 1
    total_reward += reward
print(f"Total Reward: {total_reward} & Episode length: {episode_len}")
env.close()
# Out:
# Total Reward: -13 & Episode length: 13

# %%
Q[36]
# Out:
# array([  -6.12394885, -105.56270936,   -6.56270936,   -6.56270936])

# %%
Q[35]
# Out:
# array([-1.48505, -0.995  , -0.5    , -1.48505])
